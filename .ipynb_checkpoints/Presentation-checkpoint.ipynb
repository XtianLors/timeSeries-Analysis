# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
dat = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
#Buscar alguna columna con valores únicos que se pueda utilizar como piedra angular.
print(dat['Region'].unique())

#Buscar alguna fila que pudiera Explicar eventos o que incorpore tendencias
print(dat[dat["Wealth"] > 50])

#Birth, kids able to play...

#Suicides, people struggling...


#Commerce, opportunity; Is oportunity distributed evenly. Maybe try with Area, population, donations...
# Out:
# ['E' 'N' 'C' 'S' 'W' nan]
#     dept Region           Department  Crime_pers  Crime_prop  Literacy  \
# 0      1      E                  Ain       28870       15890        37
# 2      3      C               Allier       26747        7925        13
# 3      4      E         Basses-Alpes       12935        7289        46
# 4      5      E         Hautes-Alpes       17488        8174        69
# 5      7      S              Ardeche        9474       10263        27
# 7      9      S               Ariege        6173        9597        18
# 13    15      C               Cantal       18070       11645        31
# 14    16      W             Charente       24964       13018        36
# 16    18      C                 Cher       21934       10503        13
# 17    19      C              Correze       15262       12949        12
# 19    22      W        Cotes-du-Nord       28607        7050        16
# 20    23      C               Creuse       37014       20235        23
# 21    24      W             Dordogne       21585       10237        18
# 23    26      E                Drome       13396        7759        42
# 32    35      W      Ille-et-Vilaine       22138        6524        25
# 33    36      C                Indre       32404        7624        17
# 35    38      E                Isere       18785        8326        29
# 36    39      E                 Jura       26221        8059        73
# 37    40      W               Landes       17687        6170        28
# 40    43      C          Haute-Loire       16170       18043        21
# 41    44      W     Loire-Inferieure       19314        9392        24
# 45    48      S               Lozere        7710        5990        27
# 51    54      E              Meurthe       26674        6831        68
# 52    55      N                Meuse       24507        9190        74
# 54    57      N              Moselle       12153        4529        57
# 60    63      C          Puy-de-Dome       17256       12141        19
# 61    64      W      Basses-Pyrenees       16722        8533        47
# 62    65      S      Hautes-Pyrenees       12223        9797        53
# 63    66      S  Pyrenees-Orientales        6728        7632        31
# 65    68      E            Haut-Rhin        7343        4915        71
# 67    70      E          Haute-Saone       22339        7770        59
# 79    84      S             Vaucluse       13576        5731        37
# 80    85      W               Vendee       20827        7566        28
# 81    86      W               Vienne       15010        4710        25
# 82    87      C         Haute-Vienne       16256        6402        13
# 83    88      E               Vosges       18835        9044        62
#
#     Donations  Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0        5098    33120     35039    2:Med  ...             71           60
# 2       10973    17044    114121    2:Med  ...             46           42
# 3        2733    23018     14238     1:Sm  ...             70           12
# 4        6962    23076     16171     1:Sm  ...             22           23
# 5        3188    42117     52547     1:Sm  ...             76           47
# 7        3542    22916    123625     1:Sm  ...             74           28
# 13       4093    15335     87338    2:Med  ...             79           83
# 14      13602    19454     25720    2:Med  ...              2            7
# 16       9561    23574     19497    2:Med  ...             69           11
# 17      14993    19330     47480    2:Med  ...             86           16
# 19      10387    36098     75056    2:Med  ...              6           69
# 20      10997    14363     77823     1:Sm  ...             75           24
# 21       4687    21375     36024    2:Med  ...             64           18
# 23       2829    16348     23816    2:Med  ...             21           13
# 32       7686    40736     45180    2:Med  ...             12           31
# 33      11315    20046     25014    2:Med  ...             82           19
# 35       4077    12236     36275    2:Med  ...             52           27
# 36       3012    20384     34476    2:Med  ...             84           66
# 37      12059    15302     35375     1:Sm  ...              1           43
# 40       2746    31017    163241    2:Med  ...             73           17
# 41       8310    14097     27289     3:Lg  ...             56           52
# 45       2040    25157     11092     1:Sm  ...             72           45
# 51       3912    12355     15652    2:Med  ...              5           71
# 52       4196    17333     13463    2:Med  ...             17           65
# 54       9515    13877     25572     3:Lg  ...             35            9
# 60       5963    22948     78148    2:Med  ...             42           63
# 61       3299    12393     65995    2:Med  ...             34           72
# 62       6001    12125    148039    2:Med  ...             85           75
# 63      11644    15167     37843    2:Med  ...             67           84
# 65       6001    14783     21233    2:Med  ...             40           53
# 67      11701    11850     39714     1:Sm  ...             25           68
# 79       1246    17239     19024    2:Med  ...             61           76
# 80      14035    62486     67963     1:Sm  ...             50           44
# 81       8922    35224     21851    2:Med  ...             20            1
# 82      13817    19940     33497    2:Med  ...             68            6
# 83       4040    14978     33029    2:Med  ...             58           34
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# 0                69       41         55           46           13   218.372
# 2                76       66         16           85           34   161.927
# 3                37       80         32           29            2   351.399
# 4                64       79         35            7            1   320.280
# 5                67       70         19           62            1   279.413
# 7                63       75         22           77            3   385.313
# 13               66       82          1           51           20   245.849
# 14               81       60         61           47            8   224.339
# 16               86       44         51           83           26   116.257
# 17               82       84          2           86            3   227.899
# 19               15       72         47           80           16   225.161
# 20               75       85          4           71           12   180.846
# 21               79       77         44           78            3   253.776
# 23               62       54         46           38            8   295.543
# 32               22       37         50           66           77   179.379
# 33               83       69         29           79           14   139.587
# 35               73       23         26           57           12   268.661
# 36               43       39         71            3           32   197.155
# 37               56       73         28           58            3   344.676
# 40               65       62          3           72           10   248.877
# 41               29       12         45           67           63   199.167
# 45               42       86          5           60            0   283.810
# 51                1       21         70            8          154   159.648
# 52               12       58         59            1          131   126.378
# 54                2       16         68           16          165   180.462
# 60               61       53          8           76           62   205.218
# 61               60       34          7           28           12   387.935
# 62               71       76         20           21            5   386.559
# 63               77       11         18           52            5   403.445
# 65               17       10         56            5           26   217.971
# 67               57       65         83           14           99   176.135
# 79               54        8         41           45            2   337.215
# 80               30       68         79           59            4   212.459
# 81               44       40         38           65           18   170.523
# 82               78       55         11           84            7   198.874
# 83                5       14         85           11           43   174.477
#
#     Area  Pop1831
# 0   5762   346.03
# 2   7340   298.26
# 3   6925   155.90
# 4   5549   129.10
# 5   5529   340.73
# 7   4890   253.12
# 13  5726   258.59
# 14  5956   362.53
# 16  7235   256.06
# 17  5857   294.83
# 19  6878   598.87
# 20  5565   265.38
# 21  9060   482.75
# 23  6530   299.56
# 32  6775   547.05
# 33  6791   245.29
# 35  7431   550.26
# 36  4999   312.50
# 37  9243   281.50
# 40  4977   292.08
# 41  6815   470.09
# 45  5167   140.35
# 51  5241   415.57
# 52  6216   314.59
# 54  6216   417.00
# 60  7970   573.11
# 61  7645   428.40
# 62  4464   233.03
# 63  4116   157.05
# 65  3525   424.26
# 67  5360   338.91
# 79  3567   239.11
# 80  6720   330.36
# 81  6990   282.73
# 82  5520   285.13
# 83  5874   397.99
#
# [36 rows x 23 columns]

# %%
dat[dat["Wealth"] > 50]["Wealth"].head()
# Out:
# 0    73
# 2    61
# 3    76
# 4    83
# 5    84
# Name: Wealth, dtype: int64

# %%
#For now let's focuse on Wealth
wealthRecords = len(dat["Wealth"])
print(wealthRecords)

#Wealthy percent
wealPer =  len(dat[dat["Wealth"] > 50]["Wealth"]) / wealthRecords  #36% 
hypoPer = len(dat[dat["Wealth"] < 50]["Wealth"]) / wealthRecords #49% #Makes sense assuming wealth usually concentrates among niches...

print(len(dat[dat["Wealth"] >= 50]), f"records, this corresponds to {wealPer * 100}% of people in the upper high.") #BTW if data is too predictable, like 50%-50% it might be synthetic.
print(len(dat[dat["Wealth"] < 50]), f"records, this corresponds to {hypoPer * 100}% of people in the trailing end.")
#print(len())
# Out:
# 86
# 37 records, this corresponds to 41.86046511627907% of people in the upper high.
# 49 records, this corresponds to 56.97674418604651% of people in the trailing end.

# %%
#Once acquired a broad perspective of wealth, like the media. We can continue to understand how is it distributed.
# We can use our stepping-stone dat['Region'].unique() to analyze wealth distribution inside an area.

#Para Wealth <= 50
print(len(dat[dat["Wealth"] >= 50]), f"records this corresponds to {wealPer * 100}% of people in the upper high.") #BTW if data is too predictable, like 50%-50% it might be synthetic.
upperHDat = dat[dat["Wealth"] >= 50]
regs = upperHDat["Region"].unique()

upperHDatE = upperHDat[upperHDat['Region'] == regs[0] ]
upperHDatC = upperHDat[upperHDat['Region'] == regs[1] ]
upperHDatS = upperHDat[upperHDat['Region'] == regs[2] ]
upperHDatW = upperHDat[upperHDat['Region'] == regs[3] ]
upperHDatE = upperHDat[upperHDat['Region'] == regs[4] ]

#Data 
upperHDatE.head()
# Out:
# 37 records this corresponds to 41.86046511627907% of people in the upper high.
#     dept Region Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 52    55      N      Meuse       24507        9190        74       4196
# 54    57      N    Moselle       12153        4529        57       9515
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 52    17333     13463    2:Med  ...             17           65
# 54    13877     25572     3:Lg  ...             35            9
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# 52               12       58         59            1          131   126.378
# 54                2       16         68           16          165   180.462
#
#     Area  Pop1831
# 52  6216   314.59
# 54  6216   417.00
#
# [2 rows x 23 columns]

# %%
#type(regs)
#for i in regs:
#    print(i)
print(regs[3])
# Out:
# W
