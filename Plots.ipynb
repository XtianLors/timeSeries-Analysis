# %%
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(19680801)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
#bar_labels = ['red', 'blue', 'pink', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:orange']

ax.bar(fruits, counts, label=fruits, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
fruits = ['apple', 'blueberry', 'cherry', 'orange']
print(len(fruits))
counts = [40, 100, 30, 55]
print(len(counts))
bar_labels = ['red', 'blue', '_red', 'orange']
print(len(bar_labels))
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']
print(len(bar_colors))
# Out:
# 4
# 4
# 4
# 4

# %%
fig, ax = plt.subplots()
ax.bar(["Julia", "Haskell", "Ocaml"], [100, 200, 100], 0.95, label=["Julia", "Haskell", "Ocaml"], color=['purple', 'blue', 'orange'] )
ax.set_title("Tutorial Graph Bar")
ax.legend(loc = "upper right")
plt.show()

# %%
#Lienzo
#ax -> todo lo demás (formas, figuras, estructuras, anotaciones)...
fig, ax = plt.subplots()

s = ax.bar(["Sucedáneos SAPI de CV", "Manufactura SA de CV"], [100, 150], 0.99, color=["red", "green"])
ax.bar_label(s, label_type="edge")
ax.set_title("Información de Empresas")
plt.show()

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

species = (
    "Adelie\n $\\mu=$3700.66g",
    "Chinstrap\n $\\mu=$3733.09g",
    "Gentoo\n $\\mu=5076.02g$",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, weight_count in weight_counts.items():
    p = ax.bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

ax.set_title("Number of penguins with above average body mass")
ax.legend(loc="upper right")

plt.show()

# %%
species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence


fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count

    ax.bar_label(p, label_type='center')

ax.set_title('Number of penguins by sex')
ax.legend()

plt.show()

# %%
#Data

species = (
    "Adelie\n $\\mu=$3700.66g",
    "Chinstrap\n $\\mu=$3733.09g",
    "Gentoo\n $\\mu=5076.02g$",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5
#_______________________________________________________________________________________________#

#--------------------------PLOT------------------------------------------------------------------#
fig, axs = plt.subplots(1, 2, figsize=(10, 5), tight_layout=True)
#fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# First plot
bottom = np.zeros(3)

for boolean, weight_count in weight_counts.items():
    p = axs[0].bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

axs[0].set_title("Number of penguins with above average body mass")
axs[0].legend(loc="upper right")

# Second plot
s = axs[1].bar(["Sucedáneos SAPI de CV", "Manufactura SA de CV"], [100, 150], 0.99, color=["red", "green"])
axs[1].bar_label(s, label_type="edge")
axs[1].set_title("Información de Empresas")


plt.show()

# %% [markdown]
# # Referencias
#
# + https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_stacked.html
