# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
dat = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
dat.head()
# Out:
#    dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0     1      E           Ain       28870       15890        37       5098
# 1     2      N         Aisne       26226        5521        51       8901
# 2     3      C        Allier       26747        7925        13      10973
# 3     4      E  Basses-Alpes       12935        7289        46       2733
# 4     5      E  Hautes-Alpes       17488        8174        69       6962
#
#    Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0    33120     35039    2:Med  ...             71           60
# 1    14572     12831    2:Med  ...              4           82
# 2    17044    114121    2:Med  ...             46           42
# 3    23018     14238     1:Sm  ...             70           12
# 4    23076     16171     1:Sm  ...             22           23
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
type(dat)
# Out:
# pandas.core.frame.DataFrame

# %%
dat.dtypes
# Out:
# dept                 int64
# Region              object
# Department          object
# Crime_pers           int64
# Crime_prop           int64
# Literacy             int64
# Donations            int64
# Infants              int64
# Suicides             int64
# MainCity            object
# Wealth               int64
# Commerce             int64
# Clergy               int64
# Crime_parents        int64
# Infanticide          int64
# Donation_clergy      int64
# Lottery              int64
# Desertion            int64
# Instruction          int64
# Prostitutes          int64
# Distance           float64
# Area                 int64
# Pop1831            float64
# dtype: object

# %%
print(len(dat.dtypes))
# Out:
# 23

# %%
print(dat['Region'].head())
print(len(dat['Region']))
# Out:
# 0    E
# 1    N
# 2    C
# 3    E
# 4    E
# Name: Region, dtype: object
# 86

# %%
dat['Region'].unique()
# Out:
# array(['E', 'N', 'C', 'S', 'W', nan], dtype=object)

# %%
print(len(dat['Wealth']))
print(dat['Wealth'].head())
# Out:
# 86
# 0    73
# 1    22
# 2    61
# 3    76
# 4    83
# Name: Wealth, dtype: int64

# %%
wealthyDat = dat[dat["Wealth"] > 50]

# %%
print(len(wealthyDat))
print(wealthyDat.head())
# Out:
# 36
#    dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0     1      E           Ain       28870       15890        37       5098
# 2     3      C        Allier       26747        7925        13      10973
# 3     4      E  Basses-Alpes       12935        7289        46       2733
# 4     5      E  Hautes-Alpes       17488        8174        69       6962
# 5     7      S       Ardeche        9474       10263        27       3188
#
#    Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0    33120     35039    2:Med  ...             71           60
# 2    17044    114121    2:Med  ...             46           42
# 3    23018     14238     1:Sm  ...             70           12
# 4    23076     16171     1:Sm  ...             22           23
# 5    42117     52547     1:Sm  ...             76           47
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
brokenDat = dat[dat["Wealth"] < 50]

# %%
print(len(brokenDat))
print(brokenDat.head())
# Out:
# 49
#     dept Region        Department  Crime_pers  Crime_prop  Literacy  \
# 1      2      N             Aisne       26226        5521        51
# 6      8      N          Ardennes       35203        8847        67
# 8     10      E              Aube       19602        4086        59
# 9     11      S              Aude       15647       10431        34
# 11    13      S  Bouches-du-Rhone       13409        5291        38
#
#     Donations  Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 1        8901    14572     12831    2:Med  ...              4           82
# 6        6400    16106     26198    2:Med  ...             53           85
# 8        3608    18642     10989    2:Med  ...             77           54
# 9        2582    20225     66498    2:Med  ...             80           35
# 11       2314     9325      8107     3:Lg  ...             45           74
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
print(len(dat[dat['Region'] == "E"]))
print(len(dat[dat['Region'] == "N"]))
print(len(dat[dat['Region'] == "C"]))
print(len(dat[dat['Region'] == "S"]))
print(len(dat[dat['Region'] == "W"]))
print(len(dat[dat['Region'] == np.nan]))
# Out:
# 17
# 17
# 17
# 17
# 17
# 0

# %%
wealthyDat["Region"]
brokenDat["Region"]

# %%
results = smf.ols('Lottery ~ Literacy + np.log(Pop1831)', data=dat).fit() #  include both Literacy and log(Pop1831) as separate predictors in the model.
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Mon, 24 Aug 2026   Prob (F-statistic):           1.90e-08
# Time:                        21:52:32   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         246.4341     35.233      6.995      0.000     176.358     316.510
# ...

# %%
print(len(brokenDat[brokenDat["Wealth"] < 10]))
#print(brokenDat[brokenDat["Wealth"] < 10]["Wealth"])
#print(sorted(brokenDat[brokenDat["Wealth"] < 10]["Wealth"]))
# Out:
# 9
# 11    2
# 30    8
# 42    9
# 44    7
# 66    6
# 70    1
# 71    3
# 72    4
# 73    5
# Name: Wealth, dtype: int64
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
brokenDat[brokenDat["Wealth"] < 10]
# Out:
#     dept Region        Department  Crime_pers  Crime_prop  Literacy  \
# 11    13      S  Bouches-du-Rhone       13409        5291        38
# 30    33      W           Gironde       24096        7423        40
# 42    45      C            Loiret       17722        5042        42
# 44    47      W    Lot-et-Garonne       22969        8943        31
# 66    69      E             Rhone       18793        4504        45
# 70    75      N             Seine       13945        1368        71
# 71    76      N  Seine-Inferieure       18355        2906        43
# 72    77      N    Seine-et-Marne       22201        5786        54
# 73    78      N     Seine-et-Oise       12477        3879        56
#
#     Donations  Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 11       2314     9325      8107     3:Lg  ...             45           74
# 30       5076    10676     19220     3:Lg  ...             27           80
# ...

# %%
juke = dat['Region'].unique()

# %%
for i in juke:
    print(i)
# Out:
# E
# N
# C
# S
# W
# nan

# %%
fig, ax = plt.subplots()

ax.bar()

# %% [markdown]
# ## References
#
# + https://www.statsmodels.org/stable/index.html
# + https://pandas.pydata.org/docs/user_guide/10min.html
# + https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html
# + https://pandas.pydata.org/docs/reference/api/pandas.Series.kurtosis.html
# + https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html
# + https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
# + https://pandas.pydata.org/docs/user_guide/indexing.html
# + https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_colors.html
